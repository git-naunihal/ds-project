# %%
import os

# %%
# %pwd
# Out:
# '/home/naus/Downloads/Machine Learning/ds-project'

# %%
os.chdir("../")

# %%
# Entity
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
# Configuration Manager
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config=self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config=DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
# import packages for component
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# Component for Data Transformation
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    # Note: Different data transformation techniques can be added such as Scaler, PCA and etc

    def train_test_splitting(self):
        data=pd.read_csv(self.config.data_path)

        #Split data into training and test sets (0.75, 0.25) split
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"),index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"),index = False)

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2026-03-12 17:21:14,598: INFO: common: yaml file: config/config.yaml loaded successfully: ]
# [2026-03-12 17:21:14,600: INFO: common: yaml file: params.yaml loaded successfully: ]
# [2026-03-12 17:21:14,603: INFO: common: yaml file: schema.yaml loaded successfully: ]
# [2026-03-12 17:21:14,604: INFO: common: Directory created at: artifacts: ]
# [2026-03-12 17:21:14,605: INFO: common: Directory created at: artifacts/data_transformation: ]
# [2026-03-12 17:21:14,634: INFO: 3223647511: Splited data into training and test sets: ]
# [2026-03-12 17:21:14,635: INFO: 3223647511: (1199, 12): ]
# [2026-03-12 17:21:14,636: INFO: 3223647511: (400, 12): ]
# (1199, 12)
# (400, 12)

# %%
# .split(" ")[-1]
string="Validation: True"
string.split(" ")[-1]
# Out:
# 'True'
